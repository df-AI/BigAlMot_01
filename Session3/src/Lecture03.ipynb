# %% [markdown]
# # Lecture 03. Unsupervised Learning
#
# ***
#
# > 이 장에서는 ML기법 중 하나인 비지도학습(unsupervised learning)에 대한 기초적인 알고리즘에 대해서 소개하겠습니다.
#
# ## 1. k-Means 알고리즘
#
# - 데이터 어떤 영역을 대표하는 중심을 찾아나가는 방식
# - [참조1](https://ko.wikipedia.org/wiki/K-%ED%8F%89%EA%B7%A0_%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98)
# - [참조2](http://sanghyukchun.github.io/69/)
# - [참조3](http://shiny.rstudio.com/gallery/kmeans-example.html)

# %%
import mglearn
mglearn.plots.plot_kmeans_algorithm()
